# %% [markdown]
# ## XClone CNV - Cell SNP lite

# %%
# === PARAMETERS ===
data_dir = "/home/a.blanc-boekholt/Documents/Singlecell-R/Scripts/Matrix/Cell_snp_lite/D1/"

# %%
import sys
import scanpy as sc
import numpy as np
import pandas as pd
import gc
import warnings
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import xclone
# Out:
# (Running XClone 0.4.0)
# 2026-05-18 09:14:40

# %%
AD_file = data_dir + "cellSNP.tag.AD.mtx"
DP_file = data_dir + "cellSNP.tag.DP.mtx"
mtx_barcodes_file = data_dir + "cellSNP.samples.tsv" # cell barcodes
anno_file = data_dir + "Xclone.tsv"

# %%
anno = pd.read_csv(anno_file)

print(anno.columns)
# Out:
# Index(['cell_id\tAnnotation\tcell_type\tsample\tcell'], dtype='object')

# %%
BAF_adata = xclone.pp.xclonedata([AD_file, DP_file], 'BAF',
                                 mtx_barcodes_file,
                                 genome_mode = "hg38_genes")
BAF_adata = xclone.pp.extra_anno(BAF_adata, anno_file, barcodes_key = "cell",
            cell_anno_key = ["Clone_ID", "Type", "cell_type"], sep = ",")
# Out:
# /home/a.blanc-boekholt/miniconda3/envs/xclone_env/lib/python3.11/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 4
#       1 BAF_adata = xclone.pp.xclonedata([AD_file, DP_file], 'BAF',
#       2                                  mtx_barcodes_file,
#       3                                  genome_mode = "hg38_genes")
# ----> 4 BAF_adata = xclone.pp.extra_anno(BAF_adata, anno_file, barcodes_key = "cell",
#       5             cell_anno_key = ["Clone_ID", "Type", "cell_type"], sep = ",")
#
# File ~/miniconda3/envs/xclone_env/lib/python3.11/site-packages/xclone/preprocessing/_data.py:403, in extra_anno(Xdata, anno_file, barcodes_key, cell_anno_key, sep, copy)
# ...

# %%
hg38_genes = xclone.pp.load_anno(genome_mode = "hg38_genes")
hg38_blocks = xclone.pp.load_anno(genome_mode = "hg38_blocks")
